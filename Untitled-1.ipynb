# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_excel('ALLPOKEMONDATABASE.xlsx')

# %%
data
# Out:
#       Pokédex No.                  Name              Species  Color  \
# 0               1             Bulbasaur         Seed Pokémon  Green
# 1               2               Ivysaur         Seed Pokémon  Green
# 2               3              Venusaur         Seed Pokémon  Green
# 3               3         Mega Venusaur         Seed Pokémon  Green
# 4               4            Charmander       Lizard Pokémon    Red
# ...           ...                   ...                  ...    ...
# 1027          896             Glastrier   Wild Horse Pokémon  White
# 1028          897             Spectrier  Swift Horse Pokémon  Black
# 1029          898               Calyrex         King Pokémon  Green
# 1030          898     Calyrex Ice Rider    High King Pokémon  Green
# 1031          898  Calyrex Shadow Rider    High King Pokémon  Green
#
#           Shape   Types   Type 1  Type 2 Abilities       Ability 1  ...  \
# 0     Quadruped    Dual    Grass  Poison       Two     Chlorophyll  ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1032 entries, 0 to 1031
# Data columns (total 64 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Pokédex No.                    1032 non-null   int64
#  1   Name                           1032 non-null   object
#  2   Species                        1032 non-null   object
#  3   Color                          1032 non-null   object
#  4   Shape                          1032 non-null   object
#  5   Types                          1032 non-null   object
#  6   Type 1                         1032 non-null   object
#  7   Type 2                         1032 non-null   object
#  8   Abilities                      1032 non-null   object
#  9   Ability 1                      1032 non-null   object
#  10  Ability 2                      1032 non-null   object
#  11  Ability 3                      1032 non-null   object
# ...

# %%
data.columns
# Out:
# Index(['Pokédex No.', 'Name', 'Species', 'Color', 'Shape', 'Types', 'Type 1',
#        'Type 2', 'Abilities', 'Ability 1', 'Ability 2', 'Ability 3',
#        'HP (Hit Points)', 'Attack', 'Defence', 'Special Attack',
#        'Special Defence', 'Speed', 'BST (Base Stat Total)', 'Catch Rate',
#        'Mean Score', 'Standard Deviation', 'Base Friendship',
#        'Base Experience', 'Experience Type', 'Experience to Reach Level 100',
#        'Males', 'Females', 'Generation', 'Evolution', 'Status',
#        'Mega Evolution', 'Alolan Form', 'Galarian Form', 'Egg Types',
#        'Egg Type 1', 'Egg Type 2', 'Egg Cycles', 'Total Steps',
#        'Against Normal', 'Against Fire', 'Against Water', 'Against Electric',
#        'Against Grass', 'Against Ice', 'Against Fighting', 'Against Poison',
#        'Against Ground', 'Against Flying', 'Against Psychic', 'Against Bug',
#        'Against Rock', 'Against Ghost', 'Against Dragon', 'Against Dark',
# ...

# %%
data.isnull().sum()
# Out:
# Pokédex No.              0
# Name                     0
# Species                  0
# Color                    0
# Shape                    0
#                         ..
# BMI (Body Mass Index)    0
# Game of Origin           0
# Bulbapedia URLs          0
# Gameinfo URLs            0
# Image URLs               0
# Length: 64, dtype: int64

# %%
data['Type 1'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Dark', 'Poison',
#        'Electric', 'Ground', 'Ice', 'Fairy', 'Steel', 'Fighting',
#        'Psychic', 'Rock', 'Ghost', 'Dragon', 'Flying'], dtype=object)

# %%
y = data['Type 1'].value_counts()
y
# Out:
# Water       131
# Normal      114
# Grass        91
# Bug          81
# Psychic      77
# Fire         64
# Rock         59
# Electric     59
# Dark         46
# Dragon       42
# Fighting     42
# Ground       41
# Ghost        41
# Poison       40
# Ice          38
# Steel        36
# Fairy        22
# Flying        8
# Name: Type 1, dtype: int64

# %%
z = data['Type 2'].value_counts()
z = z.iloc[1:]
type(z)
# Out:
# pandas.core.series.Series

# %%
x = data['Type 1'].describe()
x
# Out:
# count      1032
# unique       18
# top       Water
# freq        131
# Name: Type 1, dtype: object

# %%
df = pd.concat([y,z],axis=1)
df
# Out:
#           Type 1  Type 2
# Water        131      20
# Normal       114      10
# Grass         91      28
# Bug           81       9
# Psychic       77      42
# Fire          64      17
# Rock          59      15
# Electric      59      11
# Dark          46      26
# Dragon        42      30
# Fighting      42      31
# Ground        41      39
# Ghost         41      27
# Poison        40      37
# Ice           38      18
# Steel         36      35
# Fairy         22      41
# Flying         8     112

# %%
ax = df.plot(figsize=(8,5),kind='bar')
ax
# Out:
# <AxesSubplot: >

# %%
data.head()
# Out:
#    Pokédex No.           Name         Species  Color      Shape   Types  \
# 0            1      Bulbasaur    Seed Pokémon  Green  Quadruped    Dual
# 1            2        Ivysaur    Seed Pokémon  Green  Quadruped    Dual
# 2            3       Venusaur    Seed Pokémon  Green  Quadruped    Dual
# 3            3  Mega Venusaur    Seed Pokémon  Green  Quadruped    Dual
# 4            4     Charmander  Lizard Pokémon    Red    Upright  Single
#
#   Type 1  Type 2 Abilities    Ability 1  ... Against Dark       Against Steel  \
# 0  Grass  Poison       Two  Chlorophyll  ...       Normal              Normal
# 1  Grass  Poison       Two  Chlorophyll  ...       Normal              Normal
# 2  Grass  Poison       Two  Chlorophyll  ...       Normal              Normal
# 3  Grass  Poison       One    Thick Fat  ...       Normal              Normal
# 4   Fire       -       Two        Blaze  ...       Normal  Not very effective
#
# ...

# %%
data['Against Dark'].value_counts()
# Out:
# Normal                694
# Not very effective    171
# Super Effective       160
# No effect               7
# Name: Against Dark, dtype: int64

# %%
data[data['Against Dark']=='No effect']
# Out:
#       Pokédex No.                         Name           Species   Color  \
# 656           559                      Scraggy  Shedding Pokémon  Yellow
# 657           560                      Scrafty   Hoodlum Pokémon     Red
# 781           675                      Pangoro  Daunting Pokémon   White
# 986           859                     Impidimp      Wily Pokémon    Pink
# 987           860                      Morgrem   Devious Pokémon    Pink
# 988           861                   Grimmsnarl   Bulk Up Pokémon  Purple
# 1023          891  Urshifu Single Strike Style     Wushu Pokémon    Gray
#
#          Shape Types    Type 1    Type 2 Abilities    Ability 1  ...  \
# 656    Upright  Dual      Dark  Fighting     Three   Intimidate  ...
# 657    Upright  Dual      Dark  Fighting     Three   Intimidate  ...
# 781   Humanoid  Dual  Fighting      Dark     Three    Iron Fist  ...
# 986   Humanoid  Dual      Dark     Fairy     Three        Frisk  ...
# ...

# %%
data['Standard Deviation']
# Out:
# 0        8.640988
# 1        8.902247
# 2        8.902247
# 3       18.747592
# 4        8.995369
#           ...
# 1027    38.908725
# 1028    31.841622
# 1029     7.453560
# 1030    39.334746
# 1031    32.360813
# Name: Standard Deviation, Length: 1032, dtype: float64

# %%
data.columns
# Out:
# Index(['Pokédex No.', 'Name', 'Species', 'Color', 'Shape', 'Types', 'Type 1',
#        'Type 2', 'Abilities', 'Ability 1', 'Ability 2', 'Ability 3',
#        'HP (Hit Points)', 'Attack', 'Defence', 'Special Attack',
#        'Special Defence', 'Speed', 'BST (Base Stat Total)', 'Catch Rate',
#        'Mean Score', 'Standard Deviation', 'Base Friendship',
#        'Base Experience', 'Experience Type', 'Experience to Reach Level 100',
#        'Males', 'Females', 'Generation', 'Evolution', 'Status',
#        'Mega Evolution', 'Alolan Form', 'Galarian Form', 'Egg Types',
#        'Egg Type 1', 'Egg Type 2', 'Egg Cycles', 'Total Steps',
#        'Against Normal', 'Against Fire', 'Against Water', 'Against Electric',
#        'Against Grass', 'Against Ice', 'Against Fighting', 'Against Poison',
#        'Against Ground', 'Against Flying', 'Against Psychic', 'Against Bug',
#        'Against Rock', 'Against Ghost', 'Against Dragon', 'Against Dark',
# ...

# %%
data['Attack'].argmax()
# Out:
# 193

# %%
data.iloc[193]
# Out:
# Pokédex No.                                                            150
# Name                                                         Mega Mewtwo X
# Species                                                    Genetic Pokémon
# Color                                                               Purple
# Shape                                                              Upright
#                                                ...
# BMI (Body Mass Index)                                                 24.0
# Game of Origin                                                   Pokémon X
# Bulbapedia URLs          https://bulbapedia.bulbagarden.net/wiki/Mewtwo...
# Gameinfo URLs            https://pokemon.gameinfo.io/en/pokemon/150-mew...
# Image URLs               https://archives.bulbagarden.net/media/upload/...
# Name: 193, Length: 64, dtype: object

# %%
data['Attack'].argmin()
# Out:
# 146

# %%
data.iloc[146]
# Out:
# Pokédex No.                                                            113
# Name                                                               Chansey
# Species                                                        Egg Pokémon
# Color                                                                 Pink
# Shape                                                              Upright
#                                                ...
# BMI (Body Mass Index)                                                 28.6
# Game of Origin                                                 Pokémon Red
# Bulbapedia URLs          https://bulbapedia.bulbagarden.net/wiki/Chanse...
# Gameinfo URLs            https://pokemon.gameinfo.io/en/pokemon/113-cha...
# Image URLs               https://archives.bulbagarden.net/media/upload/...
# Name: 146, Length: 64, dtype: object

# %%
data['Defence'].argmax()
# Out:
# 254

# %%
data.iloc[254]
# Out:
# Pokédex No.                                                            208
# Name                                                          Mega Steelix
# Species                                                 Iron Snake Pokémon
# Color                                                                 Gray
# Shape                                                             Squiggle
#                                                ...
# BMI (Body Mass Index)                                                  6.7
# Game of Origin                                          Pokémon Omega Ruby
# Bulbapedia URLs          https://bulbapedia.bulbagarden.net/wiki/Steeli...
# Gameinfo URLs            https://pokemon.gameinfo.io/en/pokemon/208-ste...
# Image URLs               https://archives.bulbagarden.net/media/upload/...
# Name: 254, Length: 64, dtype: object

# %%
data['Defence'].argmin()
# Out:
# 146

# %%
data.iloc[146]
# Out:
# Pokédex No.                                                            113
# Name                                                               Chansey
# Species                                                        Egg Pokémon
# Color                                                                 Pink
# Shape                                                              Upright
#                                                ...
# BMI (Body Mass Index)                                                 28.6
# Game of Origin                                                 Pokémon Red
# Bulbapedia URLs          https://bulbapedia.bulbagarden.net/wiki/Chanse...
# Gameinfo URLs            https://pokemon.gameinfo.io/en/pokemon/113-cha...
# Image URLs               https://archives.bulbagarden.net/media/upload/...
# Name: 146, Length: 64, dtype: object

# %%
data['Weight'].describe()
# Out:
# count    1032.000000
# mean       71.879845
# std       132.872741
# min         0.100000
# 25%         9.000000
# 50%        29.750000
# 75%        71.275000
# max       999.900000
# Name: Weight, dtype: float64

# %%
import seaborn as sns

# %%
ax1 =
